# %%
# Cargar a la memoria de trabajo las bibliotecas: Pandas, 
# Numpy y la biblioteca de gráficas Matplotlib
# Se asignan nombres cortos.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dfDec = pd.read_csv('ValentiaDec.txt', skiprows=3, sep='\s+')
dfJun = pd.read_csv('ValentiaJun.txt', skiprows=3, sep='\s+')
dfDec.columns = ['PRES', 'HGHT', 'TEMP', 'DWPT', 'RELH', 'MIXR', 'DRCT', 'SKNT', 'THTA', 'THTE', 'THTV']
dfJun.columns = ['PRES', 'HGHT', 'TEMP', 'DWPT', 'RELH', 'MIXR', 'DRCT', 'SKNT', 'THTA', 'THTE', 'THTV']

# %%
dfDec = dfDec.drop([0])
dfJun = dfJun.drop([0])
dfDec = dfDec[:-26]
dfJun = dfJun[:-26]

# %%
col = ['PRES', 'HGHT', 'TEMP', 'DWPT', 'RELH', 'MIXR', 'DRCT', 'SKNT', 'THTA', 'THTE', 'THTV']
dfDec[col] = dfDec[col].apply(pd.to_numeric, errors='coerce', axis=1)
dfJun[col] = dfJun[col].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
dfJun.dtypes
# Out:
# PRES    float64
# HGHT    float64
# TEMP    float64
# DWPT    float64
# RELH    float64
# MIXR    float64
# DRCT    float64
# SKNT    float64
# THTA    float64
# THTE    float64
# THTV    float64
# dtype: object

# %%
dfDec.head()
# Out:
#      PRES   HGHT  TEMP  DWPT  RELH  MIXR   DRCT  SKNT   THTA   THTE   THTV
# 1  1037.0   30.0   9.8   9.6  99.0  7.28  310.0   4.0  280.0  300.0  281.3
# 2  1032.0   69.0  15.2   3.2  45.0  4.69  312.0   4.0  285.8  299.2  286.6
# 3  1026.0  116.0   9.6   6.5  81.0  5.95  314.0   5.0  280.7  297.2  281.7
# 4  1000.0  319.0   8.2   7.6  96.0  6.59  325.0   8.0  281.4  299.6  282.5
# 5   952.0  724.0   6.6   5.4  92.0  5.94  319.0  13.0  283.7  300.4  284.7

# %%
dfJun.tail()
# Out:
#     PRES     HGHT  TEMP  DWPT  RELH  MIXR   DRCT   SKNT   THTA   THTE   THTV
# 72  14.0  29267.0 -41.4 -76.9   1.0  0.08  130.0   16.0  784.7  785.6  784.7
# 73  11.7  30485.0 -41.1 -77.1   1.0  0.09   97.0   21.0  827.0  828.1  827.1
# 74  11.0  30907.0 -39.6 -76.0   1.0  0.11   85.0   23.0  847.2  848.6  847.2
# 75  10.0  31560.0 -37.3 -74.3   1.0  0.16   95.0   17.0  879.1  881.2  879.2
# 76   9.0  32291.0 -35.3 -72.3   1.0  0.24  913.7  916.9  913.8    NaN    NaN

# %%
#Gráfica de la variación de la presión con respecto a la altura.

#Datos de 22 de Diciembre 2017, Valentia Observatory.
presD = dfDec['PRES']
altD = dfDec['HGHT']
plt.plot(presD, altD, "blue", label='PRES'); plt.legend(loc='best')
plt.title('Presión con respecto a la Altura - Diciembre')
plt.ylabel('Altura (m)')
plt.xlabel('Presión (hPa)')
plt.grid(True)
plt.show()

#Datos de 22 de Junio 2017, Valentia Observatory.
presJ = dfJun['PRES']
altJ = dfJun['HGHT']
plt.plot(presJ, altJ, "red", label='PRES'); plt.legend(loc='best')
plt.title('Presión con respecto a la Altura - Junio')
plt.ylabel('Altura (m)')
plt.xlabel('Presión (hPa)')
plt.grid(True)
plt.show()

# %%
#Gráfica de la varciación de la temperatura con respecto a la altura.

#Datos de 22 de Diciembre 2917, Valentia Observatory.
tempD = dfDec['TEMP']
altD = dfDec['HGHT']
plt.plot(tempD, altD, "blue", label='TEMP'); plt.legend(loc='best')
plt.title('Temperatura con respecto a la Altura - Diciembre')
plt.ylabel('Altura (m)')
plt.xlabel('Temperatura (C)')
plt.grid(True)
plt.show()

#Datos de 22 de Junio 2017, Valentia Observatory.
tempJ = dfJun['TEMP']
altJ = dfJun['HGHT']
plt.plot(tempJ, altJ, "red", label='TEMP'); plt.legend(loc='best')
plt.title('Temperatura con respecto a la Alutra - Junio')
plt.ylabel('Altura (m)')
plt.xlabel('Temperatura (C)')
plt.grid(True)
plt.show()

# %%
#Gráfica de la temperatura (TEMP) y temperatura de rocío (DEWPT), como función de la altura.

#Datos de 22 de Diciembre 2917, Valentia Observatory
tempD = dfDec['TEMP']
dwptD = dfDec['DWPT']
altD = dfDec['HGHT']
plt.plot(tempD, altD, "blue", label='TEMP')
plt.plot(dwptD, altD, "cyan", label='DWPT'); plt.legend(loc='best')
plt.title('Temperatura y Temperatura de Rocío con respecto a la Altura - Diciembre')
plt.ylabel('Altura (m)')
plt.xlabel('Temperatura (C)')
plt.grid(True)
plt.show()

#Datos de 22 de Diciembre 2917, Valentia Observatory
tempJ = dfJun['TEMP']
dwptJ = dfJun['DWPT']
altJ = dfJun['HGHT']
plt.plot(tempJ, altJ, "red", label='TEMP')
plt.plot(dwptJ, altJ, "orange", label='DWPT'); plt.legend(loc='best')
plt.title('Temperatura y Temperatura de Rocío con respecto a la Altura - Junio')
plt.ylabel('Altura (m)')
plt.xlabel('Temperatura (C)')
plt.grid(True)
plt.show()

# %%
#Gráfica de la rapidez de los vientos en nudos.

#Datos de 22 de Diciembre 2017, Valentia Observatory.
rapD = dfDec['SKNT']
altD = dfDec['HGHT']
plt.plot(rapD, altD, "blue", label='SKNT'); plt.legend(loc='best')
plt.title("Rapidez de los Vientos - Diciembre")
plt.ylabel("Altura (m)")
plt.xlabel("Rapidez (nudos)")
plt.xlim([0,80])
plt.ylim([0,30000])
plt.grid(True)
plt.show()

#Datos de 22 de Junio 2017, Valentia Observatory.
rapJ = dfJun['SKNT']
altJ = dfJun['HGHT']
plt.title("Rapidez de los Vientos - Junio")
plt.plot(rapJ, altJ, "red", label='SKNT'); plt.legend(loc='best')
plt.ylabel("Altura (m)")
plt.xlabel("Rapidez (nudos)")
plt.xlim([0,75])
plt.ylim([0,30000])
plt.grid(True)
plt.show()

# %%
#Gráfica de la humedad relativa como función de la altura.  

#Datos de 22 de Diciembre 2017, Valentia Observatory.
humD = dfDec['RELH']
altD = dfDec['HGHT']
plt.plot(humD, altD, "blue", label='RELH'); plt.legend(loc='best')
plt.title('Humedad Relativa con respecto a la Altura - Diciembre')
plt.xlabel('Humedad Relativa (%)')
plt.ylabel('Altura (m)')
plt.grid(True)
plt.show()

#Datos de 22 de Junio 2017, Valentia Observatory.
humJ = dfJun['RELH']
altJ = dfJun['HGHT']
plt.plot(humJ, altJ, "red", label='RELH'); plt.legend(loc='best')
plt.title('Humedad Relativa con respecto a la Altura - Junio')
plt.xlabel('Humedad Relativa (%)')
plt.ylabel('Altura (m)')
plt.grid(True)
plt.show()
